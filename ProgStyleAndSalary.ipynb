# %% [markdown]
# ### What kind of programming style would affect salary
#
# This section will look into the factors of programming style (what kind of IDE they use, space type) would contribute to salary, in order to determine the contribution, we build machine learning model to predict salary.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import r2_score, mean_squared_error
from collections import defaultdict
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize       ...       StackOverflowMakeMoney Gender  \
# 0                       NaN       ...            Strongly disagree   Male
# 1        20 to 99 employees       ...            Strongly disagree   Male
# 2  10,000 or more employees       ...                     Disagree   Male
# 3  10,000 or more employees       ...                     Disagree   Male
# 4        10 to 19 employees       ...                          NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %% [markdown]
# ### Data understanding and preparation
# We will firstly extract all the programming style related columns and create dummy columns as they are categorical columns.

# %%
sal_rm = df.dropna(subset=['Salary'], axis=0)
sal_nona = df.dropna(subset=['Salary', 'TabsSpaces', 'WorkStart', 'HaveWorkedLanguage', 
                             'HaveWorkedFramework', 'HaveWorkedDatabase', 'HaveWorkedPlatform', 'IDE', 
                             'AuditoryEnvironment', 'Methodology', 'VersionControl', 'CheckInCode'], axis=0)

# %%
sal_rm
# Out:
#        Respondent            Professional  \
# 2               3  Professional developer
# 14             15  Professional developer
# 17             18  Professional developer
# 18             19  Professional developer
# 22             23  Professional developer
# 25             26  Professional developer
# 34             35  Professional developer
# 36             37  Professional developer
# 37             38  Professional developer
# 52             53  Professional developer
# 54             55  Professional developer
# 57             58  Professional developer
# 61             62  Professional developer
# 64             65  Professional developer
# 65             66  Professional developer
# 69             70  Professional developer
# 70             71  Professional developer
# 72             73  Professional developer
# 75             76  Professional developer
# 76             77  Professional developer
# 81             82  Professional developer
# 83             84  Professional developer
# 89             90  Professional developer
# 90             91  Professional developer
# 95             96  Professional developer
# 97             98  Professional developer
# 99            100  Professional developer
# 102           103  Professional developer
# 103           104  Professional developer
# 104           105  Professional developer
# ...           ...                     ...
# 18945       18946  Professional developer
# 18946       18947  Professional developer
# 18947       18948  Professional developer
# 18950       18951  Professional developer
# 18955       18956  Professional developer
# 18964       18965  Professional developer
# 18984       18985  Professional developer
# 18985       18986  Professional developer
# 18989       18990  Professional developer
# 18990       18991  Professional developer
# 18996       18997  Professional developer
# 19004       19005  Professional developer
# 19005       19006  Professional developer
# 19006       19007  Professional developer
# 19011       19012  Professional developer
# 19014       19015  Professional developer
# 19016       19017  Professional developer
# 19018       19019  Professional developer
# 19020       19021  Professional developer
# 19022       19023  Professional developer
# 19039       19040  Professional developer
# 19045       19046  Professional developer
# 19046       19047  Professional developer
# 19055       19056  Professional developer
# 19073       19074  Professional developer
# 19079       19080  Professional developer
# 19086       19087  Professional developer
# 19088       19089  Professional developer
# 19089       19090  Professional developer
# 19100       19101  Professional developer
#
#                                     ProgramHobby         Country  \
# 2                                      Yes, both  United Kingdom
# 14                     Yes, I program as a hobby  United Kingdom
# 17                                     Yes, both   United States
# 18                     Yes, I program as a hobby   United States
# 22                                            No          Israel
# 25                     Yes, I program as a hobby   United States
# 34                     Yes, I program as a hobby         Croatia
# 36                     Yes, I program as a hobby       Argentina
# 37                                     Yes, both         Germany
# 52                     Yes, I program as a hobby          Brazil
# 54                                            No         Germany
# 57                                     Yes, both           Italy
# 61                     Yes, I program as a hobby           India
# 64                                            No     Netherlands
# 65                     Yes, I program as a hobby          Poland
# 69                     Yes, I program as a hobby           Spain
# 70                     Yes, I program as a hobby   United States
# 72                                     Yes, both   United States
# 75                                     Yes, both          France
# 76                                     Yes, both   United States
# 81                     Yes, I program as a hobby   United States
# 83                                     Yes, both   United States
# 89                     Yes, I program as a hobby          Brazil
# 90                                     Yes, both         Croatia
# 95     Yes, I contribute to open source projects         Germany
# 97                                            No          Turkey
# 99                                     Yes, both   United States
# 102                                    Yes, both         Germany
# 103                                           No   United States
# 104                                           No          Brazil
# ...                                          ...             ...
# 18945                  Yes, I program as a hobby   United States
# 18946                  Yes, I program as a hobby          France
# 18947                  Yes, I program as a hobby        Bulgaria
# 18950                  Yes, I program as a hobby  United Kingdom
# 18955                                  Yes, both  United Kingdom
# 18964                                         No          Poland
# 18984                  Yes, I program as a hobby  United Kingdom
# 18985                                  Yes, both   United States
# 18989                                         No   United States
# 18990                  Yes, I program as a hobby  United Kingdom
# 18996                  Yes, I program as a hobby  United Kingdom
# 19004  Yes, I contribute to open source projects         Ukraine
# 19005                                         No   United States
# 19006                  Yes, I program as a hobby   United States
# 19011                  Yes, I program as a hobby     South Korea
# 19014                  Yes, I program as a hobby   United States
# 19016                  Yes, I program as a hobby           Italy
# 19018                                         No          France
# 19020                  Yes, I program as a hobby         Germany
# 19022                  Yes, I program as a hobby          Sweden
# 19039                                  Yes, both        Bulgaria
# 19045                                         No     Netherlands
# 19046                                  Yes, both  United Kingdom
# 19055                                  Yes, both   United States
# 19073                  Yes, I program as a hobby  United Kingdom
# 19079                  Yes, I program as a hobby   United States
# 19086                                         No         Germany
# 19088                  Yes, I program as a hobby  United Kingdom
# 19089                  Yes, I program as a hobby  United Kingdom
# 19100                  Yes, I program as a hobby   United States
#
#            University    EmploymentStatus  \
# 2                  No  Employed full-time
# 14                 No  Employed full-time
# 17     Yes, part-time  Employed full-time
# 18                 No  Employed full-time
# 22                 No  Employed full-time
# 25                 No  Employed full-time
# 34     Yes, full-time  Employed full-time
# 36                 No  Employed full-time
# 37                 No  Employed full-time
# 52                 No  Employed full-time
# 54                 No  Employed full-time
# 57                 No  Employed full-time
# 61                 No  Employed full-time
# 64                 No  Employed full-time
# 65                 No  Employed full-time
# 69                 No  Employed full-time
# 70                 No  Employed full-time
# 72                 No  Employed full-time
# 75                 No  Employed full-time
# 76                 No  Employed full-time
# 81                 No  Employed full-time
# 83                 No  Employed full-time
# 89                 No  Employed full-time
# 90                 No  Employed full-time
# 95                 No  Employed full-time
# 97                 No  Employed full-time
# 99                 No  Employed full-time
# 102                No  Employed full-time
# 103                No  Employed full-time
# 104                No  Employed full-time
# ...               ...                 ...
# 18945              No  Employed full-time
# 18946              No  Employed full-time
# 18947              No  Employed full-time
# 18950              No  Employed full-time
# 18955              No  Employed full-time
# 18964  Yes, full-time  Employed full-time
# 18984              No  Employed full-time
# 18985              No  Employed full-time
# 18989              No  Employed full-time
# 18990              No  Employed full-time
# 18996              No  Employed full-time
# 19004              No  Employed full-time
# 19005              No  Employed full-time
# 19006              No  Employed full-time
# 19011              No  Employed full-time
# 19014              No  Employed full-time
# 19016  Yes, part-time  Employed full-time
# 19018  Yes, part-time  Employed full-time
# 19020  Yes, full-time  Employed part-time
# 19022              No  Employed full-time
# 19039              No  Employed full-time
# 19045              No  Employed full-time
# 19046              No  Employed full-time
# 19055              No  Employed full-time
# 19073              No  Employed full-time
# 19079              No  Employed full-time
# 19086  Yes, part-time  Employed full-time
# 19088              No  Employed full-time
# 19089              No  Employed full-time
# 19100              No  Employed full-time
#
#                                          FormalEducation  \
# 2                                      Bachelor's degree
# 14                                   Professional degree
# 17                                     Bachelor's degree
# 18                                     Bachelor's degree
# 22                                     Bachelor's degree
# 25                                       Master's degree
# 34                                     Bachelor's degree
# 36     Some college/university study without earning ...
# 37     Some college/university study without earning ...
# 52                                     Bachelor's degree
# 54                                       Master's degree
# 57                                       Master's degree
# 61                                     Bachelor's degree
# 64                                       Master's degree
# 65                                     Bachelor's degree
# 69                                     Bachelor's degree
# 70     Some college/university study without earning ...
# 72     Some college/university study without earning ...
# 75                                       Master's degree
# 76     Some college/university study without earning ...
# 81                                     Bachelor's degree
# 83                                       Doctoral degree
# 89                                     Bachelor's degree
# 90                                     Bachelor's degree
# 95                                     Bachelor's degree
# 97                                     Bachelor's degree
# 99                                       Master's degree
# 102                                      Master's degree
# 103                                    Bachelor's degree
# 104                                    Bachelor's degree
# ...                                                  ...
# 18945  Some college/university study without earning ...
# 18946                                    Master's degree
# 18947                                    Master's degree
# 18950                                  Bachelor's degree
# 18955                                   Secondary school
# 18964                                    Master's degree
# 18984                                  Bachelor's degree
# 18985  Some college/university study without earning ...
# 18989                                  Bachelor's degree
# 18990                                    Master's degree
# 18996                                  Bachelor's degree
# 19004                                    Master's degree
# 19005  Some college/university study without earning ...
# 19006                                  Bachelor's degree
# 19011                                    Master's degree
# 19014  Some college/university study without earning ...
# 19016                                   Secondary school
# 19018                                    Master's degree
# 19020                                   Secondary school
# 19022                                   Secondary school
# 19039                                  Bachelor's degree
# 19045                                  Bachelor's degree
# 19046                                    Master's degree
# 19055                                    Master's degree
# 19073                                    Master's degree
# 19079                                  Bachelor's degree
# 19086                                Professional degree
# 19088                                  Bachelor's degree
# 19089  Some college/university study without earning ...
# 19100  Some college/university study without earning ...
#
#                                           MajorUndergrad  \
# 2               Computer science or software engineering
# 14     Computer engineering or electrical/electronics...
# 17              Computer science or software engineering
# 18              Computer science or software engineering
# 22     Computer engineering or electrical/electronics...
# 25              Computer science or software engineering
# 34     Computer engineering or electrical/electronics...
# 36               Computer programming or Web development
# 37                             Mathematics or statistics
# 52     Computer engineering or electrical/electronics...
# 54              Computer science or software engineering
# 57              Computer science or software engineering
# 61              Computer science or software engineering
# 64              Computer science or software engineering
# 65              Computer science or software engineering
# 69               Computer programming or Web development
# 70     Information technology, networking, or system ...
# 72              Computer science or software engineering
# 75                             Mathematics or statistics
# 76     Computer engineering or electrical/electronics...
# 81              Computer science or software engineering
# 83              Computer science or software engineering
# 89              Computer science or software engineering
# 90              Computer science or software engineering
# 95                        Management information systems
# 97              Computer science or software engineering
# 99              Computer science or software engineering
# 102    Computer engineering or electrical/electronics...
# 103                                       Something else
# 104             Computer science or software engineering
# ...                                                  ...
# 18945           Computer science or software engineering
# 18946           Computer science or software engineering
# 18947           Computer science or software engineering
# 18950           Computer science or software engineering
# 18955                                                NaN
# 18964           Computer science or software engineering
# 18984                                     Something else
# 18985                                         Psychology
# 18989                              A business discipline
# 18990           Computer science or software engineering
# 18996                                  A natural science
# 19004           Computer science or software engineering
# 19005      A non-computer-focused engineering discipline
# 19006  Computer engineering or electrical/electronics...
# 19011           Computer science or software engineering
# 19014            Computer programming or Web development
# 19016                                                NaN
# 19018           Computer science or software engineering
# 19020                                                NaN
# 19022                                                NaN
# 19039           Computer science or software engineering
# 19045           Computer science or software engineering
# 19046  Computer engineering or electrical/electronics...
# 19055           Computer science or software engineering
# 19073           Computer science or software engineering
# 19079           Computer science or software engineering
# 19086                     Management information systems
# 19088                            A humanities discipline
# 19089  Information technology, networking, or system ...
# 19100                            A humanities discipline
#
#                                               HomeRemote  \
# 2      Less than half the time, but at least one day ...
# 14     All or almost all the time (I'm full-time remote)
# 17     All or almost all the time (I'm full-time remote)
# 18                                 A few days each month
# 22                                 A few days each month
# 25     Less than half the time, but at least one day ...
# 34                                 A few days each month
# 36                                 A few days each month
# 37     All or almost all the time (I'm full-time remote)
# 52                                 A few days each month
# 54                                 A few days each month
# 57                                 A few days each month
# 61                                 A few days each month
# 64                                 A few days each month
# 65                                                 Never
# 69                                                 Never
# 70                                 A few days each month
# 72     All or almost all the time (I'm full-time remote)
# 75                                                 Never
# 76                 More than half, but not all, the time
# 81                                 A few days each month
# 83                                 A few days each month
# 89     All or almost all the time (I'm full-time remote)
# 90                                 A few days each month
# 95                                                 Never
# 97                                 A few days each month
# 99                                                 Never
# 102                                A few days each month
# 103                                                Never
# 104                                                Never
# ...                                                  ...
# 18945  All or almost all the time (I'm full-time remote)
# 18946                                              Never
# 18947                                              Never
# 18950                              A few days each month
# 18955                              A few days each month
# 18964                                              Never
# 18984  All or almost all the time (I'm full-time remote)
# 18985                              A few days each month
# 18989                              A few days each month
# 18990                                              Never
# 18996                              A few days each month
# 19004  Less than half the time, but at least one day ...
# 19005                              A few days each month
# 19006                                About half the time
# 19011                                   It's complicated
# 19014  Less than half the time, but at least one day ...
# 19016                                              Never
# 19018                              A few days each month
# 19020  All or almost all the time (I'm full-time remote)
# 19022                                              Never
# 19039                                About half the time
# 19045                                   It's complicated
# 19046                              A few days each month
# 19055                              A few days each month
# 19073              More than half, but not all, the time
# 19079                                              Never
# 19086                              A few days each month
# 19088                                   It's complicated
# 19089                              A few days each month
# 19100  Less than half the time, but at least one day ...
#
#                     CompanySize       ...       StackOverflowMakeMoney  \
# 2      10,000 or more employees       ...                     Disagree
# 14     5,000 to 9,999 employees       ...                     Disagree
# 17     1,000 to 4,999 employees       ...                     Disagree
# 18     10,000 or more employees       ...                          NaN
# 22         500 to 999 employees       ...               Somewhat agree
# 25     10,000 or more employees       ...                     Disagree
# 34           10 to 19 employees       ...            Strongly disagree
# 36         500 to 999 employees       ...                     Disagree
# 37         100 to 499 employees       ...                     Disagree
# 52     1,000 to 4,999 employees       ...                     Disagree
# 54     1,000 to 4,999 employees       ...                     Disagree
# 57         100 to 499 employees       ...                          NaN
# 61     5,000 to 9,999 employees       ...            Strongly disagree
# 64     10,000 or more employees       ...                     Disagree
# 65           20 to 99 employees       ...                     Disagree
# 69           20 to 99 employees       ...                          NaN
# 70           20 to 99 employees       ...            Strongly disagree
# 72         100 to 499 employees       ...                     Disagree
# 75         500 to 999 employees       ...                     Disagree
# 76     1,000 to 4,999 employees       ...                     Disagree
# 81           20 to 99 employees       ...               Somewhat agree
# 83     10,000 or more employees       ...               Somewhat agree
# 89           20 to 99 employees       ...                     Disagree
# 90           10 to 19 employees       ...                     Disagree
# 95     5,000 to 9,999 employees       ...               Somewhat agree
# 97         100 to 499 employees       ...                     Disagree
# 99           20 to 99 employees       ...                     Disagree
# 102          20 to 99 employees       ...                          NaN
# 103          20 to 99 employees       ...                     Disagree
# 104    1,000 to 4,999 employees       ...                          NaN
# ...                         ...       ...                          ...
# 18945      500 to 999 employees       ...                     Disagree
# 18946      100 to 499 employees       ...                     Disagree
# 18947   Fewer than 10 employees       ...                          NaN
# 18950        10 to 19 employees       ...                     Disagree
# 18955        20 to 99 employees       ...               Somewhat agree
# 18964      100 to 499 employees       ...            Strongly disagree
# 18984        20 to 99 employees       ...                          NaN
# 18985      100 to 499 employees       ...                          NaN
# 18989        20 to 99 employees       ...            Strongly disagree
# 18990  1,000 to 4,999 employees       ...            Strongly disagree
# 18996      100 to 499 employees       ...            Strongly disagree
# 19004  10,000 or more employees       ...                     Disagree
# 19005  1,000 to 4,999 employees       ...                          NaN
# 19006   Fewer than 10 employees       ...                        Agree
# 19011        10 to 19 employees       ...                     Disagree
# 19014  1,000 to 4,999 employees       ...                          NaN
# 19016        20 to 99 employees       ...                          NaN
# 19018      500 to 999 employees       ...                          NaN
# 19020        10 to 19 employees       ...            Strongly disagree
# 19022      100 to 499 employees       ...                          NaN
# 19039        20 to 99 employees       ...                        Agree
# 19045  1,000 to 4,999 employees       ...               Strongly agree
# 19046  5,000 to 9,999 employees       ...            Strongly disagree
# 19055  10,000 or more employees       ...                     Disagree
# 19073   Fewer than 10 employees       ...                          NaN
# 19079   Fewer than 10 employees       ...                          NaN
# 19086      100 to 499 employees       ...                     Disagree
# 19088        10 to 19 employees       ...                     Disagree
# 19089    I prefer not to answer       ...                     Disagree
# 19100      100 to 499 employees       ...                     Disagree
#
#                     Gender                            HighestEducationParents  \
# 2                     Male                              A professional degree
# 14                    Male                                        High school
# 17                    Male                                  A master's degree
# 18                     NaN                                                NaN
# 22                    Male                                A bachelor's degree
# 25                    Male                                  A master's degree
# 34                    Male                                  A master's degree
# 36                    Male                                A bachelor's degree
# 37                    Male                                  A master's degree
# 52                    Male                                  A doctoral degree
# 54                    Male                                  A master's degree
# 57                    Male                          Primary/elementary school
# 61                    Male                                A bachelor's degree
# 64                    Male                                  A doctoral degree
# 65                    Male                                        High school
# 69                     NaN                                                NaN
# 70                    Male                                        High school
# 72                    Male                                A bachelor's degree
# 75                    Male                                  A master's degree
# 76                    Male  Some college/university study, no bachelor's d...
# 81                    Male                                A bachelor's degree
# 83                    Male                                  A doctoral degree
# 89                    Male                                        High school
# 90                    Male                                A bachelor's degree
# 95                    Male                                        High school
# 97                    Male                          Primary/elementary school
# 99                    Male                                  A master's degree
# 102                   Male                                  A master's degree
# 103                 Female                                A bachelor's degree
# 104                   Male                                A bachelor's degree
# ...                    ...                                                ...
# 18945                 Male                              I don't know/not sure
# 18946                 Male                             I prefer not to answer
# 18947                 Male                                  A master's degree
# 18950                 Male                                  A master's degree
# 18955                Other                                  A master's degree
# 18964                 Male                                  A master's degree
# 18984  Female; Transgender                                  A doctoral degree
# 18985                 Male  Some college/university study, no bachelor's d...
# 18989                 Male                                  A master's degree
# 18990                 Male                                A bachelor's degree
# 18996                 Male                                        High school
# 19004                 Male                                  A master's degree
# 19005                  NaN                                                NaN
# 19006                 Male                                  A master's degree
# 19011                 Male                             I prefer not to answer
# 19014                  NaN                                                NaN
# 19016                  NaN                                                NaN
# 19018                  NaN                                                NaN
# 19020                 Male                                        High school
# 19022                 Male                                        High school
# 19039                 Male                                  A master's degree
# 19045                 Male                                        High school
# 19046                 Male                                  A master's degree
# 19055                 Male                              A professional degree
# 19073                  NaN                                                NaN
# 19079                 Male                                        High school
# 19086                 Male                              A professional degree
# 19088                 Male                                A bachelor's degree
# 19089                 Male  Some college/university study, no bachelor's d...
# 19100                 Male  Some college/university study, no bachelor's d...
#
#                                                     Race      SurveyLong  \
# 2                           White or of European descent  Somewhat agree
# 14                          White or of European descent  Somewhat agree
# 17     Native American, Pacific Islander, or Indigeno...        Disagree
# 18                                                   NaN             NaN
# 22                          White or of European descent  Strongly agree
# 25                          White or of European descent        Disagree
# 34                          White or of European descent        Disagree
# 36                             Hispanic or Latino/Latina  Somewhat agree
# 37                          White or of European descent  Somewhat agree
# 52     Hispanic or Latino/Latina; White or of Europea...  Somewhat agree
# 54     Hispanic or Latino/Latina; White or of Europea...  Strongly agree
# 57                          White or of European descent        Disagree
# 61                                           South Asian           Agree
# 64                          White or of European descent  Strongly agree
# 65                                        Middle Eastern           Agree
# 69                                                   NaN             NaN
# 70                          White or of European descent        Disagree
# 72                          White or of European descent        Disagree
# 75                          White or of European descent        Disagree
# 76                          White or of European descent        Disagree
# 81                          White or of European descent        Disagree
# 83                          White or of European descent           Agree
# 89                             Hispanic or Latino/Latina  Strongly agree
# 90                          White or of European descent           Agree
# 95                          White or of European descent           Agree
# 97                          White or of European descent  Somewhat agree
# 99                          White or of European descent           Agree
# 102                         White or of European descent  Somewhat agree
# 103                         White or of European descent  Somewhat agree
# 104                         White or of European descent  Somewhat agree
# ...                                                  ...             ...
# 18945                       White or of European descent        Disagree
# 18946           East Asian; White or of European descent  Somewhat agree
# 18947                       White or of European descent           Agree
# 18950                       White or of European descent        Disagree
# 18955                       White or of European descent  Somewhat agree
# 18964                       White or of European descent        Disagree
# 18984                       White or of European descent           Agree
# 18985                       White or of European descent           Agree
# 18989                       White or of European descent  Somewhat agree
# 18990                       White or of European descent        Disagree
# 18996                       White or of European descent        Disagree
# 19004                       White or of European descent  Strongly agree
# 19005                                                NaN             NaN
# 19006                       White or of European descent  Strongly agree
# 19011                                         East Asian  Strongly agree
# 19014                                                NaN             NaN
# 19016                                                NaN             NaN
# 19018                                                NaN             NaN
# 19020                       White or of European descent  Somewhat agree
# 19022                       White or of European descent  Strongly agree
# 19039                       White or of European descent  Strongly agree
# 19045                       White or of European descent  Somewhat agree
# 19046                       White or of European descent  Somewhat agree
# 19055                                        South Asian           Agree
# 19073                                                NaN             NaN
# 19079                       White or of European descent  Somewhat agree
# 19086                       White or of European descent  Strongly agree
# 19088                       White or of European descent           Agree
# 19089                       White or of European descent        Disagree
# 19100                       White or of European descent  Somewhat agree
#
#       QuestionsInteresting QuestionsConfusing InterestedAnswers  \
# 2                    Agree           Disagree             Agree
# 14                   Agree           Disagree             Agree
# 17                   Agree           Disagree             Agree
# 18                     NaN                NaN               NaN
# 22          Somewhat agree     Somewhat agree             Agree
# 25          Strongly agree           Disagree    Strongly agree
# 34                   Agree  Strongly disagree             Agree
# 36                   Agree  Strongly disagree    Strongly agree
# 37                   Agree           Disagree             Agree
# 52                   Agree           Disagree    Strongly agree
# 54                Disagree  Strongly disagree             Agree
# 57                   Agree           Disagree             Agree
# 61          Strongly agree           Disagree    Strongly agree
# 64          Somewhat agree           Disagree             Agree
# 65          Somewhat agree     Somewhat agree    Somewhat agree
# 69                     NaN                NaN               NaN
# 70          Somewhat agree           Disagree             Agree
# 72          Somewhat agree  Strongly disagree             Agree
# 75                   Agree           Disagree             Agree
# 76          Somewhat agree           Disagree    Somewhat agree
# 81          Somewhat agree           Disagree    Strongly agree
# 83          Somewhat agree           Disagree             Agree
# 89          Somewhat agree           Disagree             Agree
# 90          Somewhat agree           Disagree          Disagree
# 95          Somewhat agree           Disagree             Agree
# 97          Somewhat agree           Disagree    Strongly agree
# 99          Somewhat agree              Agree    Strongly agree
# 102         Somewhat agree           Disagree             Agree
# 103                  Agree           Disagree             Agree
# 104                  Agree           Disagree    Strongly agree
# ...                    ...                ...               ...
# 18945                Agree           Disagree    Strongly agree
# 18946                Agree  Strongly disagree             Agree
# 18947       Somewhat agree  Strongly disagree             Agree
# 18950       Somewhat agree           Disagree    Strongly agree
# 18955                  NaN           Disagree    Strongly agree
# 18964                Agree           Disagree    Strongly agree
# 18984       Somewhat agree           Disagree             Agree
# 18985                Agree           Disagree    Strongly agree
# 18989                Agree  Strongly disagree    Strongly agree
# 18990                Agree           Disagree    Strongly agree
# 18996                Agree           Disagree    Strongly agree
# 19004       Somewhat agree           Disagree    Strongly agree
# 19005                  NaN                NaN               NaN
# 19006       Somewhat agree           Disagree             Agree
# 19011    Strongly disagree           Disagree             Agree
# 19014                  NaN                NaN               NaN
# 19016                  NaN                NaN               NaN
# 19018                  NaN                NaN               NaN
# 19020       Somewhat agree           Disagree             Agree
# 19022       Somewhat agree           Disagree             Agree
# 19039       Somewhat agree           Disagree    Somewhat agree
# 19045       Strongly agree           Disagree             Agree
# 19046                Agree  Strongly disagree    Strongly agree
# 19055       Somewhat agree           Disagree    Strongly agree
# 19073                  NaN                NaN               NaN
# 19079                Agree           Disagree    Strongly agree
# 19086       Somewhat agree     Somewhat agree             Agree
# 19088             Disagree  Strongly disagree    Strongly agree
# 19089       Somewhat agree           Disagree             Agree
# 19100       Somewhat agree           Disagree             Agree
#
#               Salary  ExpectedSalary
# 2      113750.000000             NaN
# 14     100000.000000             NaN
# 17     130000.000000             NaN
# 18      82500.000000             NaN
# 22     100764.000000             NaN
# 25     175000.000000             NaN
# 34      14838.709677             NaN
# 36      28200.000000             NaN
# 37     118279.569892             NaN
# 52      15674.203822             NaN
# 54      64516.129032             NaN
# 57      43010.752688             NaN
# 61       6636.323594             NaN
# 64      69892.473118             NaN
# 65      17777.777778             NaN
# 69      32258.064516             NaN
# 70      65000.000000             NaN
# 72     120000.000000             NaN
# 75      46236.559140             NaN
# 76      96283.000000             NaN
# 81     110000.000000             NaN
# 83     165000.000000             NaN
# 89     113694.267516             NaN
# 90      38600.000000             NaN
# 95      53763.440860             NaN
# 97      27548.209366             NaN
# 99     109400.000000             NaN
# 102     83870.967742             NaN
# 103     51000.000000             NaN
# 104     17515.923567             NaN
# ...              ...             ...
# 18945  121500.000000             NaN
# 18946   38709.677419             NaN
# 18947     405.405405             NaN
# 18950   43750.000000             NaN
# 18955   23750.000000             NaN
# 18964   32962.962963             NaN
# 18984   37500.000000             NaN
# 18985  150000.000000             NaN
# 18989  155000.000000             NaN
# 18990   62500.000000             NaN
# 18996   37500.000000             NaN
# 19004    2040.740741             NaN
# 19005   65000.000000             NaN
# 19006   65000.000000             NaN
# 19011   31393.614888             NaN
# 19014   70000.000000             NaN
# 19016   18279.569892             NaN
# 19018   34408.602151             NaN
# 19020    5376.344086             NaN
# 19022   28506.787330             NaN
# 19039    2972.972973             NaN
# 19045   43010.752688             NaN
# 19046   43750.000000             NaN
# 19055  140000.000000             NaN
# 19073   87500.000000             NaN
# 19079   65000.000000             NaN
# 19086   80645.161290             NaN
# 19088   41250.000000             NaN
# 19089   50500.000000             NaN
# 19100  110000.000000             NaN
#
# [5009 rows x 154 columns]

# %%
sal_nona
# Out:
#        Respondent            Professional  \
# 37             38  Professional developer
# 52             53  Professional developer
# 64             65  Professional developer
# 72             73  Professional developer
# 83             84  Professional developer
# 133           134  Professional developer
# 143           144  Professional developer
# 146           147  Professional developer
# 156           157  Professional developer
# 173           174  Professional developer
# 177           178  Professional developer
# 180           181  Professional developer
# 206           207  Professional developer
# 211           212  Professional developer
# 215           216  Professional developer
# 234           235  Professional developer
# 258           259  Professional developer
# 260           261  Professional developer
# 264           265  Professional developer
# 284           285  Professional developer
# 329           330  Professional developer
# 331           332  Professional developer
# 340           341  Professional developer
# 349           350  Professional developer
# 364           365  Professional developer
# 373           374  Professional developer
# 374           375  Professional developer
# 378           379  Professional developer
# 397           398  Professional developer
# 398           399  Professional developer
# ...           ...                     ...
# 18630       18631  Professional developer
# 18633       18634  Professional developer
# 18655       18656  Professional developer
# 18666       18667  Professional developer
# 18668       18669  Professional developer
# 18690       18691  Professional developer
# 18696       18697  Professional developer
# 18699       18700  Professional developer
# 18718       18719  Professional developer
# 18723       18724  Professional developer
# 18756       18757  Professional developer
# 18762       18763  Professional developer
# 18773       18774  Professional developer
# 18801       18802  Professional developer
# 18804       18805  Professional developer
# 18820       18821  Professional developer
# 18821       18822  Professional developer
# 18898       18899  Professional developer
# 18902       18903  Professional developer
# 18905       18906  Professional developer
# 18909       18910  Professional developer
# 18917       18918  Professional developer
# 18940       18941  Professional developer
# 18985       18986  Professional developer
# 18996       18997  Professional developer
# 19006       19007  Professional developer
# 19011       19012  Professional developer
# 19022       19023  Professional developer
# 19079       19080  Professional developer
# 19089       19090  Professional developer
#
#                                     ProgramHobby             Country  \
# 37                                     Yes, both             Germany
# 52                     Yes, I program as a hobby              Brazil
# 64                                            No         Netherlands
# 72                                     Yes, both       United States
# 83                                     Yes, both       United States
# 133                                    Yes, both               India
# 143                                    Yes, both      United Kingdom
# 146                    Yes, I program as a hobby             Denmark
# 156                                           No       United States
# 173                                    Yes, both             Ukraine
# 177                    Yes, I program as a hobby       United States
# 180                                    Yes, both  Russian Federation
# 206                                           No              Canada
# 211                    Yes, I program as a hobby              Poland
# 215                                    Yes, both               India
# 234                    Yes, I program as a hobby       United States
# 258                                           No       United States
# 260                    Yes, I program as a hobby      United Kingdom
# 264                                           No          Costa Rica
# 284    Yes, I contribute to open source projects               India
# 329                    Yes, I program as a hobby      United Kingdom
# 331                                           No         El Salvador
# 340                    Yes, I program as a hobby             Germany
# 349                                    Yes, both       United States
# 364                    Yes, I program as a hobby       United States
# 373                                    Yes, both       United States
# 374                                    Yes, both       United States
# 378                                    Yes, both       United States
# 397                                           No         Switzerland
# 398                                    Yes, both              Sweden
# ...                                          ...                 ...
# 18630                                  Yes, both             Romania
# 18633                                  Yes, both             Germany
# 18655  Yes, I contribute to open source projects         Netherlands
# 18666                  Yes, I program as a hobby             Germany
# 18668                                         No            Pakistan
# 18690  Yes, I contribute to open source projects              France
# 18696                  Yes, I program as a hobby              Brazil
# 18699                  Yes, I program as a hobby      United Kingdom
# 18718                                  Yes, both             Germany
# 18723                  Yes, I program as a hobby             Romania
# 18756                                  Yes, both              Norway
# 18762                  Yes, I program as a hobby             Finland
# 18773                                  Yes, both      United Kingdom
# 18801                                  Yes, both        South Africa
# 18804                                  Yes, both               India
# 18820                  Yes, I program as a hobby               Spain
# 18821                  Yes, I program as a hobby             Denmark
# 18898                                  Yes, both             Germany
# 18902                                  Yes, both         Netherlands
# 18905                  Yes, I program as a hobby       United States
# 18909                                  Yes, both              Sweden
# 18917                  Yes, I program as a hobby            Malaysia
# 18940                                  Yes, both             Germany
# 18985                                  Yes, both       United States
# 18996                  Yes, I program as a hobby      United Kingdom
# 19006                  Yes, I program as a hobby       United States
# 19011                  Yes, I program as a hobby         South Korea
# 19022                  Yes, I program as a hobby              Sweden
# 19079                  Yes, I program as a hobby       United States
# 19089                  Yes, I program as a hobby      United Kingdom
#
#            University    EmploymentStatus  \
# 37                 No  Employed full-time
# 52                 No  Employed full-time
# 64                 No  Employed full-time
# 72                 No  Employed full-time
# 83                 No  Employed full-time
# 133                No  Employed full-time
# 143                No  Employed full-time
# 146    Yes, part-time  Employed part-time
# 156                No  Employed full-time
# 173                No  Employed full-time
# 177    Yes, part-time  Employed full-time
# 180                No  Employed full-time
# 206                No  Employed full-time
# 211                No  Employed full-time
# 215                No  Employed full-time
# 234                No  Employed full-time
# 258                No  Employed full-time
# 260                No  Employed full-time
# 264                No  Employed full-time
# 284                No  Employed full-time
# 329                No  Employed full-time
# 331                No  Employed full-time
# 340                No  Employed full-time
# 349                No  Employed full-time
# 364                No  Employed full-time
# 373                No  Employed full-time
# 374                No  Employed full-time
# 378                No  Employed full-time
# 397                No  Employed full-time
# 398                No  Employed full-time
# ...               ...                 ...
# 18630              No  Employed full-time
# 18633              No  Employed full-time
# 18655              No  Employed full-time
# 18666              No  Employed part-time
# 18668              No  Employed full-time
# 18690              No  Employed full-time
# 18696              No  Employed full-time
# 18699              No  Employed full-time
# 18718              No  Employed full-time
# 18723  Yes, full-time  Employed part-time
# 18756              No  Employed full-time
# 18762              No  Employed full-time
# 18773              No  Employed full-time
# 18801              No  Employed full-time
# 18804              No  Employed full-time
# 18820  Yes, full-time  Employed full-time
# 18821  Yes, full-time  Employed full-time
# 18898              No  Employed full-time
# 18902              No  Employed full-time
# 18905              No  Employed full-time
# 18909              No  Employed full-time
# 18917              No  Employed full-time
# 18940              No  Employed full-time
# 18985              No  Employed full-time
# 18996              No  Employed full-time
# 19006              No  Employed full-time
# 19011              No  Employed full-time
# 19022              No  Employed full-time
# 19079              No  Employed full-time
# 19089              No  Employed full-time
#
#                                          FormalEducation  \
# 37     Some college/university study without earning ...
# 52                                     Bachelor's degree
# 64                                       Master's degree
# 72     Some college/university study without earning ...
# 83                                       Doctoral degree
# 133                                    Bachelor's degree
# 143                                    Bachelor's degree
# 146    Some college/university study without earning ...
# 156                                    Bachelor's degree
# 173                                      Master's degree
# 177                                    Bachelor's degree
# 180                                     Secondary school
# 206                                    Bachelor's degree
# 211                                    Bachelor's degree
# 215                                    Bachelor's degree
# 234                                    Bachelor's degree
# 258                                    Bachelor's degree
# 260                                      Master's degree
# 264    Some college/university study without earning ...
# 284                                    Bachelor's degree
# 329                                    Bachelor's degree
# 331                                    Bachelor's degree
# 340                                      Master's degree
# 349                                    Bachelor's degree
# 364                                      Master's degree
# 373                                    Bachelor's degree
# 374                                    Bachelor's degree
# 378                            Primary/elementary school
# 397                            Primary/elementary school
# 398                                    Bachelor's degree
# ...                                                  ...
# 18630                                  Bachelor's degree
# 18633                                    Master's degree
# 18655                                  Bachelor's degree
# 18666                                  Bachelor's degree
# 18668                                  Bachelor's degree
# 18690                                    Master's degree
# 18696                                  Bachelor's degree
# 18699                                  Bachelor's degree
# 18718                                  Bachelor's degree
# 18723                                  Bachelor's degree
# 18756                                    Master's degree
# 18762                                  Bachelor's degree
# 18773  Some college/university study without earning ...
# 18801  Some college/university study without earning ...
# 18804                                    Master's degree
# 18820                                  Bachelor's degree
# 18821                                  Bachelor's degree
# 18898                                   Secondary school
# 18902  Some college/university study without earning ...
# 18905                                  Bachelor's degree
# 18909                                    Master's degree
# 18917                                  Bachelor's degree
# 18940                                  Bachelor's degree
# 18985  Some college/university study without earning ...
# 18996                                  Bachelor's degree
# 19006                                  Bachelor's degree
# 19011                                    Master's degree
# 19022                                   Secondary school
# 19079                                  Bachelor's degree
# 19089  Some college/university study without earning ...
#
#                                           MajorUndergrad  \
# 37                             Mathematics or statistics
# 52     Computer engineering or electrical/electronics...
# 64              Computer science or software engineering
# 72              Computer science or software engineering
# 83              Computer science or software engineering
# 133             Computer science or software engineering
# 143             Computer science or software engineering
# 146             Computer science or software engineering
# 156             Computer science or software engineering
# 173             Computer science or software engineering
# 177             Computer science or software engineering
# 180                                                  NaN
# 206             Computer science or software engineering
# 211                              A humanities discipline
# 215             Computer science or software engineering
# 234             Computer science or software engineering
# 258                                A business discipline
# 260                                    A natural science
# 264             Computer science or software engineering
# 284             Computer science or software engineering
# 329             Computer science or software engineering
# 331             Computer science or software engineering
# 340             Computer science or software engineering
# 349                              A humanities discipline
# 364                                     A social science
# 373                       Management information systems
# 374             Computer science or software engineering
# 378                                                  NaN
# 397                                                  NaN
# 398             Computer science or software engineering
# ...                                                  ...
# 18630           Computer science or software engineering
# 18633           Computer science or software engineering
# 18655           Computer science or software engineering
# 18666           Computer science or software engineering
# 18668           Computer science or software engineering
# 18690           Computer science or software engineering
# 18696           Computer science or software engineering
# 18699           Computer science or software engineering
# 18718           Computer science or software engineering
# 18723           Computer science or software engineering
# 18756            Computer programming or Web development
# 18762           Computer science or software engineering
# 18773           Computer science or software engineering
# 18801            Computer programming or Web development
# 18804           Computer science or software engineering
# 18820            Computer programming or Web development
# 18821  Computer engineering or electrical/electronics...
# 18898                                                NaN
# 18902  Computer engineering or electrical/electronics...
# 18905                                     Something else
# 18909                                  A natural science
# 18917           Computer science or software engineering
# 18940            Computer programming or Web development
# 18985                                         Psychology
# 18996                                  A natural science
# 19006  Computer engineering or electrical/electronics...
# 19011           Computer science or software engineering
# 19022                                                NaN
# 19079           Computer science or software engineering
# 19089  Information technology, networking, or system ...
#
#                                               HomeRemote  \
# 37     All or almost all the time (I'm full-time remote)
# 52                                 A few days each month
# 64                                 A few days each month
# 72     All or almost all the time (I'm full-time remote)
# 83                                 A few days each month
# 133                                A few days each month
# 143                                                Never
# 146                                A few days each month
# 156                                A few days each month
# 173    Less than half the time, but at least one day ...
# 177                                A few days each month
# 180    All or almost all the time (I'm full-time remote)
# 206                                A few days each month
# 211                                     It's complicated
# 215                                A few days each month
# 234    Less than half the time, but at least one day ...
# 258                                                Never
# 260                                     It's complicated
# 264                                  About half the time
# 284                                A few days each month
# 329                                A few days each month
# 331                                                Never
# 340                                A few days each month
# 349                                     It's complicated
# 364                                                Never
# 373                                A few days each month
# 374                                A few days each month
# 378                                A few days each month
# 397                                                Never
# 398                                                Never
# ...                                                  ...
# 18630                                              Never
# 18633                                   It's complicated
# 18655                              A few days each month
# 18666  Less than half the time, but at least one day ...
# 18668                              A few days each month
# 18690                                              Never
# 18696                                              Never
# 18699                                   It's complicated
# 18718                              A few days each month
# 18723  Less than half the time, but at least one day ...
# 18756                                              Never
# 18762  Less than half the time, but at least one day ...
# 18773                                              Never
# 18801                                   It's complicated
# 18804  Less than half the time, but at least one day ...
# 18820                                              Never
# 18821                                              Never
# 18898  All or almost all the time (I'm full-time remote)
# 18902  Less than half the time, but at least one day ...
# 18905  Less than half the time, but at least one day ...
# 18909                              A few days each month
# 18917                              A few days each month
# 18940  Less than half the time, but at least one day ...
# 18985                              A few days each month
# 18996                              A few days each month
# 19006                                About half the time
# 19011                                   It's complicated
# 19022                                              Never
# 19079                                              Never
# 19089                              A few days each month
#
#                     CompanySize       ...       StackOverflowMakeMoney  \
# 37         100 to 499 employees       ...                     Disagree
# 52     1,000 to 4,999 employees       ...                     Disagree
# 64     10,000 or more employees       ...                     Disagree
# 72         100 to 499 employees       ...                     Disagree
# 83     10,000 or more employees       ...               Somewhat agree
# 133     Fewer than 10 employees       ...            Strongly disagree
# 143     Fewer than 10 employees       ...                     Disagree
# 146        100 to 499 employees       ...            Strongly disagree
# 156        500 to 999 employees       ...            Strongly disagree
# 173        100 to 499 employees       ...               Somewhat agree
# 177          20 to 99 employees       ...               Strongly agree
# 180          10 to 19 employees       ...                     Disagree
# 206          20 to 99 employees       ...            Strongly disagree
# 211     Fewer than 10 employees       ...               Somewhat agree
# 215          20 to 99 employees       ...                     Disagree
# 234          20 to 99 employees       ...            Strongly disagree
# 258          10 to 19 employees       ...                     Disagree
# 260        500 to 999 employees       ...               Somewhat agree
# 264        100 to 499 employees       ...               Somewhat agree
# 284    10,000 or more employees       ...                     Disagree
# 329    10,000 or more employees       ...            Strongly disagree
# 331          10 to 19 employees       ...                     Disagree
# 340          20 to 99 employees       ...               Somewhat agree
# 349          20 to 99 employees       ...            Strongly disagree
# 364    10,000 or more employees       ...            Strongly disagree
# 373    1,000 to 4,999 employees       ...                     Disagree
# 374        100 to 499 employees       ...            Strongly disagree
# 378          20 to 99 employees       ...               Somewhat agree
# 397    10,000 or more employees       ...               Somewhat agree
# 398          20 to 99 employees       ...               Somewhat agree
# ...                         ...       ...                          ...
# 18630        10 to 19 employees       ...            Strongly disagree
# 18633   Fewer than 10 employees       ...                     Disagree
# 18655      500 to 999 employees       ...                     Disagree
# 18666  1,000 to 4,999 employees       ...                     Disagree
# 18668        20 to 99 employees       ...            Strongly disagree
# 18690        20 to 99 employees       ...                     Disagree
# 18696        20 to 99 employees       ...                     Disagree
# 18699      500 to 999 employees       ...            Strongly disagree
# 18718        10 to 19 employees       ...                          NaN
# 18723      500 to 999 employees       ...            Strongly disagree
# 18756      500 to 999 employees       ...                     Disagree
# 18762        20 to 99 employees       ...            Strongly disagree
# 18773  5,000 to 9,999 employees       ...            Strongly disagree
# 18801        20 to 99 employees       ...                          NaN
# 18804  5,000 to 9,999 employees       ...                          NaN
# 18820        20 to 99 employees       ...               Somewhat agree
# 18821   Fewer than 10 employees       ...            Strongly disagree
# 18898        10 to 19 employees       ...                     Disagree
# 18902      100 to 499 employees       ...                          NaN
# 18905        10 to 19 employees       ...                     Disagree
# 18909      100 to 499 employees       ...                     Disagree
# 18917      100 to 499 employees       ...                     Disagree
# 18940        20 to 99 employees       ...                     Disagree
# 18985      100 to 499 employees       ...                          NaN
# 18996      100 to 499 employees       ...            Strongly disagree
# 19006   Fewer than 10 employees       ...                        Agree
# 19011        10 to 19 employees       ...                     Disagree
# 19022      100 to 499 employees       ...                          NaN
# 19079   Fewer than 10 employees       ...                          NaN
# 19089    I prefer not to answer       ...                     Disagree
#
#                                    Gender  \
# 37                                   Male
# 52                                   Male
# 64                                   Male
# 72                                   Male
# 83                                   Male
# 133                                  Male
# 143                                  Male
# 146                                  Male
# 156                                  Male
# 173                                  Male
# 177                                  Male
# 180                                  Male
# 206                                  Male
# 211                                  Male
# 215                                  Male
# 234                                  Male
# 258                                  Male
# 260                                  Male
# 264                                  Male
# 284                                  Male
# 329                                  Male
# 331                                  Male
# 340                                  Male
# 349                                  Male
# 364                                  Male
# 373                                  Male
# 374                                  Male
# 378                   Female; Transgender
# 397                                  Male
# 398                                  Male
# ...                                   ...
# 18630                                Male
# 18633                                Male
# 18655                                Male
# 18666                              Female
# 18668                                Male
# 18690  Transgender; Gender non-conforming
# 18696                                Male
# 18699                                Male
# 18718                                Male
# 18723                                Male
# 18756                                Male
# 18762                                Male
# 18773                                Male
# 18801                                Male
# 18804                                Male
# 18820                                Male
# 18821                                Male
# 18898                                Male
# 18902                                Male
# 18905                         Male; Other
# 18909                                Male
# 18917                                Male
# 18940                                Male
# 18985                                Male
# 18996                                Male
# 19006                                Male
# 19011                                Male
# 19022                                Male
# 19079                                Male
# 19089                                Male
#
#                                  HighestEducationParents  \
# 37                                     A master's degree
# 52                                     A doctoral degree
# 64                                     A doctoral degree
# 72                                   A bachelor's degree
# 83                                     A doctoral degree
# 133                                  A bachelor's degree
# 143                                  A bachelor's degree
# 146    Some college/university study, no bachelor's d...
# 156    Some college/university study, no bachelor's d...
# 173                                    A master's degree
# 177                                  A bachelor's degree
# 180                                  A bachelor's degree
# 206                                  A bachelor's degree
# 211                                          High school
# 215                                          High school
# 234                                    A master's degree
# 258    Some college/university study, no bachelor's d...
# 260    Some college/university study, no bachelor's d...
# 264                                          High school
# 284                                  A bachelor's degree
# 329                                          High school
# 331                                  A bachelor's degree
# 340    Some college/university study, no bachelor's d...
# 349                                    A master's degree
# 364    Some college/university study, no bachelor's d...
# 373                                  A bachelor's degree
# 374                                    A master's degree
# 378                                    A master's degree
# 397                            Primary/elementary school
# 398                                  A bachelor's degree
# ...                                                  ...
# 18630                          Primary/elementary school
# 18633                                  A master's degree
# 18655                                  A master's degree
# 18666                          Primary/elementary school
# 18668                                A bachelor's degree
# 18690                                  A doctoral degree
# 18696                                A bachelor's degree
# 18699                              I don't know/not sure
# 18718                                  A doctoral degree
# 18723                                A bachelor's degree
# 18756                                  A master's degree
# 18762                                  A master's degree
# 18773                                        High school
# 18801                                        High school
# 18804                                A bachelor's degree
# 18820                                        High school
# 18821                                  A master's degree
# 18898  Some college/university study, no bachelor's d...
# 18902  Some college/university study, no bachelor's d...
# 18905                                        High school
# 18909                                        High school
# 18917                                        High school
# 18940                                A bachelor's degree
# 18985  Some college/university study, no bachelor's d...
# 18996                                        High school
# 19006                                  A master's degree
# 19011                             I prefer not to answer
# 19022                                        High school
# 19079                                        High school
# 19089  Some college/university study, no bachelor's d...
#
#                                                     Race         SurveyLong  \
# 37                          White or of European descent     Somewhat agree
# 52     Hispanic or Latino/Latina; White or of Europea...     Somewhat agree
# 64                          White or of European descent     Strongly agree
# 72                          White or of European descent           Disagree
# 83                          White or of European descent              Agree
# 133                                          South Asian     Somewhat agree
# 143                         White or of European descent     Somewhat agree
# 146                         White or of European descent     Strongly agree
# 156                         White or of European descent           Disagree
# 173                         White or of European descent     Somewhat agree
# 177                         White or of European descent     Strongly agree
# 180                         White or of European descent     Strongly agree
# 206                         White or of European descent              Agree
# 211                         White or of European descent     Somewhat agree
# 215                                          South Asian     Strongly agree
# 234                         White or of European descent  Strongly disagree
# 258                         White or of European descent     Somewhat agree
# 260                         White or of European descent           Disagree
# 264                            Hispanic or Latino/Latina              Agree
# 284                                          South Asian     Strongly agree
# 329                         White or of European descent     Somewhat agree
# 331                            Hispanic or Latino/Latina              Agree
# 340                         White or of European descent           Disagree
# 349                         White or of European descent           Disagree
# 364                         White or of European descent     Somewhat agree
# 373                         White or of European descent           Disagree
# 374                         White or of European descent           Disagree
# 378                         White or of European descent           Disagree
# 397                         White or of European descent     Somewhat agree
# 398                         White or of European descent           Disagree
# ...                                                  ...                ...
# 18630                       White or of European descent     Somewhat agree
# 18633                       White or of European descent     Strongly agree
# 18655                       White or of European descent     Somewhat agree
# 18666                       White or of European descent           Disagree
# 18668                                        South Asian     Strongly agree
# 18690                       White or of European descent           Disagree
# 18696                                       I don’t know     Somewhat agree
# 18699                       White or of European descent           Disagree
# 18718                       White or of European descent     Somewhat agree
# 18723                                       I don’t know     Somewhat agree
# 18756                       White or of European descent              Agree
# 18762                       White or of European descent     Somewhat agree
# 18773                       White or of European descent           Disagree
# 18801                        Black or of African descent              Agree
# 18804                                                NaN     Strongly agree
# 18820                       White or of European descent              Agree
# 18821                       White or of European descent              Agree
# 18898                       White or of European descent     Strongly agree
# 18902                       White or of European descent              Agree
# 18905                       White or of European descent           Disagree
# 18909                       White or of European descent     Strongly agree
# 18917                            East Asian; South Asian           Disagree
# 18940                       White or of European descent     Somewhat agree
# 18985                       White or of European descent              Agree
# 18996                       White or of European descent           Disagree
# 19006                       White or of European descent     Strongly agree
# 19011                                         East Asian     Strongly agree
# 19022                       White or of European descent     Strongly agree
# 19079                       White or of European descent     Somewhat agree
# 19089                       White or of European descent           Disagree
#
#       QuestionsInteresting QuestionsConfusing  InterestedAnswers  \
# 37                   Agree           Disagree              Agree
# 52                   Agree           Disagree     Strongly agree
# 64          Somewhat agree           Disagree              Agree
# 72          Somewhat agree  Strongly disagree              Agree
# 83          Somewhat agree           Disagree              Agree
# 133                  Agree  Strongly disagree     Strongly agree
# 143         Somewhat agree           Disagree     Strongly agree
# 146               Disagree  Strongly disagree     Somewhat agree
# 156                  Agree           Disagree     Strongly agree
# 173         Somewhat agree     Somewhat agree     Strongly agree
# 177      Strongly disagree  Strongly disagree  Strongly disagree
# 180         Somewhat agree           Disagree              Agree
# 206                  Agree           Disagree              Agree
# 211         Somewhat agree           Disagree              Agree
# 215         Somewhat agree           Disagree              Agree
# 234         Strongly agree  Strongly disagree     Strongly agree
# 258         Somewhat agree           Disagree     Somewhat agree
# 260         Somewhat agree           Disagree     Strongly agree
# 264         Somewhat agree           Disagree              Agree
# 284         Somewhat agree           Disagree     Strongly agree
# 329         Somewhat agree           Disagree              Agree
# 331         Somewhat agree     Somewhat agree              Agree
# 340                  Agree           Disagree              Agree
# 349         Somewhat agree  Strongly disagree     Strongly agree
# 364                  Agree           Disagree     Strongly agree
# 373                  Agree           Disagree              Agree
# 374                  Agree           Disagree              Agree
# 378         Somewhat agree  Strongly disagree     Strongly agree
# 397                  Agree           Disagree              Agree
# 398         Somewhat agree           Disagree     Strongly agree
# ...                    ...                ...                ...
# 18630                Agree           Disagree     Strongly agree
# 18633             Disagree     Somewhat agree              Agree
# 18655                Agree  Strongly disagree              Agree
# 18666                Agree     Somewhat agree     Strongly agree
# 18668       Somewhat agree              Agree     Strongly agree
# 18690       Somewhat agree           Disagree              Agree
# 18696                Agree           Disagree     Somewhat agree
# 18699       Strongly agree  Strongly disagree     Strongly agree
# 18718       Somewhat agree  Strongly disagree              Agree
# 18723       Strongly agree  Strongly disagree     Strongly agree
# 18756                Agree           Disagree              Agree
# 18762                Agree           Disagree              Agree
# 18773                Agree           Disagree     Strongly agree
# 18801       Strongly agree  Strongly disagree     Strongly agree
# 18804             Disagree           Disagree     Strongly agree
# 18820                Agree           Disagree     Strongly agree
# 18821                Agree           Disagree              Agree
# 18898                Agree  Strongly disagree     Strongly agree
# 18902                Agree           Disagree              Agree
# 18905       Somewhat agree           Disagree     Somewhat agree
# 18909                Agree           Disagree              Agree
# 18917       Somewhat agree           Disagree              Agree
# 18940       Somewhat agree           Disagree              Agree
# 18985                Agree           Disagree     Strongly agree
# 18996                Agree           Disagree     Strongly agree
# 19006       Somewhat agree           Disagree              Agree
# 19011    Strongly disagree           Disagree              Agree
# 19022       Somewhat agree           Disagree              Agree
# 19079                Agree           Disagree     Strongly agree
# 19089       Somewhat agree           Disagree              Agree
#
#               Salary  ExpectedSalary
# 37     118279.569892             NaN
# 52      15674.203822             NaN
# 64      69892.473118             NaN
# 72     120000.000000             NaN
# 83     165000.000000             NaN
# 133     14682.131846             NaN
# 143     43750.000000             NaN
# 146     51282.051282             NaN
# 156     80000.000000             NaN
# 173     27000.000000             NaN
# 177    120000.000000             NaN
# 180     60000.000000             NaN
# 206     62121.212121             NaN
# 211      1481.481481             NaN
# 215      4404.639554             NaN
# 234     63000.000000             NaN
# 258     65000.000000             NaN
# 260     63750.000000             NaN
# 264     59000.000000             NaN
# 284     14682.131846             NaN
# 329     62500.000000             NaN
# 331       600.000000             NaN
# 340     53763.440860             NaN
# 349     85000.000000             NaN
# 364    165000.000000             NaN
# 373    150000.000000             NaN
# 374     82000.000000             NaN
# 378     85000.000000             NaN
# 397     63500.000000             NaN
# 398     47511.312217             NaN
# ...              ...             ...
# 18630   32258.064516             NaN
# 18633   56774.193548             NaN
# 18655   59744.086022             NaN
# 18666   59139.784946             NaN
# 18668    1221.374046             NaN
# 18690   32258.064516             NaN
# 18696    7643.312102             NaN
# 18699   37500.000000             NaN
# 18718   53763.440860             NaN
# 18723   15591.397849             NaN
# 18756   76555.023923             NaN
# 18762   55913.978495             NaN
# 18773   45000.000000             NaN
# 18801   35634.743875             NaN
# 18804   13213.918661             NaN
# 18820   10322.580645             NaN
# 18821   69559.139785             NaN
# 18898   38709.677419             NaN
# 18902   75268.817204             NaN
# 18905  105000.000000             NaN
# 18909   65158.371041             NaN
# 18917    1345.291480             NaN
# 18940   64516.129032             NaN
# 18985  150000.000000             NaN
# 18996   37500.000000             NaN
# 19006   65000.000000             NaN
# 19011   31393.614888             NaN
# 19022   28506.787330             NaN
# 19079   65000.000000             NaN
# 19089   50500.000000             NaN
#
# [1429 rows x 154 columns]

# %% [markdown]
# We can see that if we remove all the null values, there would only be 1429 rows left comparing to the salary remove only option (5009 rows). Hence it's better to inpute the null values of categorical data with an additional N/A column.

# %%
dev_style_cols = ['TabsSpaces', 'WorkStart', 'HaveWorkedLanguage', 'HaveWorkedFramework', 'HaveWorkedDatabase',
            'HaveWorkedPlatform', 'IDE', 'AuditoryEnvironment', 'Methodology', 'VersionControl', 'CheckInCode']
prog_style_df = sal_rm[dev_style_cols]
salary = sal_rm['Salary']

def create_dummy_df(df, cat_cols, dummy_na):
    '''
    INPUT:
    df - pandas dataframe with categorical variables you want to dummy
    cat_cols - list of strings that are associated with names of the categorical columns
    dummy_na - Bool holding whether you want to dummy NA vals of categorical columns or not
    
    OUTPUT:
    df - a new dataframe that has the following characteristics:
            1. contains all columns that were not specified as categorical
            2. removes all the original columns in cat_cols
            3. dummy columns for each of the categorical columns in cat_cols
            4. if dummy_na is True - it also contains dummy columns for the NaN values
            5. Use a prefix of the column name with an underscore (_) for separating 
    '''
    for col in  cat_cols:
        try:
            # for each cat add dummy var, drop original column
            df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_', drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

def CategorizeSalary(salary):
    result = pd.qcut(salary, 10, labels=False)
    return result

prog_style_dummy = create_dummy_df(prog_style_df, dev_style_cols, True)
prog_style_dummy.head()
# Out:
#     TabsSpaces_Spaces  TabsSpaces_Tabs  TabsSpaces_nan  WorkStart_10:00 PM  \
# 2                   1                0               0                   0
# 14                  1                0               0                   0
# 17                  1                0               0                   0
# 18                  0                0               1                   0
# 22                  0                0               0                   0
#
#     WorkStart_11:00 AM  WorkStart_11:00 PM  WorkStart_1:00 AM  \
# 2                    0                   0                  0
# 14                   0                   0                  0
# 17                   0                   0                  0
# 18                   0                   0                  0
# 22                   0                   0                  0
#
#     WorkStart_1:00 PM  WorkStart_2:00 AM  WorkStart_2:00 PM       ...         \
# 2                   0                  0                  0       ...
# 14                  0                  0                  0       ...
# 17                  0                  0                  0       ...
# 18                  0                  0                  0       ...
# 22                  0                  0                  0       ...
#
#     VersionControl_Team Foundation Server  VersionControl_Visual Source Safe  \
# 2                                       0                                  0
# 14                                      0                                  0
# 17                                      0                                  0
# 18                                      0                                  0
# 22                                      0                                  0
#
#     VersionControl_Zip file back-ups  VersionControl_nan  \
# 2                                  0                   0
# 14                                 0                   0
# 17                                 0                   1
# 18                                 0                   1
# 22                                 0                   0
#
#     CheckInCode_A few times a week  \
# 2                                0
# 14                               0
# 17                               0
# 18                               0
# 22                               0
#
#     CheckInCode_Just a few times over the year  \
# 2                                            0
# 14                                           0
# 17                                           0
# 18                                           0
# 22                                           0
#
#     CheckInCode_Multiple times a day  CheckInCode_Never  \
# 2                                  1                  0
# 14                                 1                  0
# 17                                 0                  0
# 18                                 0                  0
# 22                                 1                  0
#
#     CheckInCode_Once a day  CheckInCode_nan
# 2                        0                0
# 14                       0                0
# 17                       0                1
# 18                       0                1
# 22                       0                0
#
# [5 rows x 4051 columns]

# %% [markdown]
# ### Modelling
# We will firstly try to use linear regression model to predict salary. If linear regression does not work very well we will try logistic regression.

# %%
X = prog_style_dummy
min_max_scaler = preprocessing.MinMaxScaler()
#y = min_max_scaler.fit_transform(salary.values.reshape(-1, 1))
y_cat = CategorizeSalary(salary)

X_train, X_test, y_train, y_test = train_test_split(X, y_cat , test_size=.30, random_state=42)

lm_model = LinearRegression(normalize = True) # Instantiate
lm_model.fit(X_train, y_train) #Fit

tree_model = DecisionTreeRegressor()
tree_model.fit(X_train, y_train)

#Predict using your model
y_test_preds = lm_model.predict(X_test)
y_train_preds = lm_model.predict(X_train)

y_test_preds_tree = tree_model.predict(X_test)
y_train_preds_tree = tree_model.predict(X_train)

#Score using your model
test_score = r2_score(y_test, y_test_preds)
train_score = r2_score(y_train, y_train_preds)

test_score_tree = r2_score(y_test, y_test_preds_tree)
train_score_tree = r2_score(y_train, y_train_preds_tree)
print("The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score, test_score))
print("LOGIS: The rsquared on the training data was {}.  The rsquared on the test data was {}.".format(train_score_tree, test_score_tree))
# Out:
# The rsquared on the training data was 0.24269874093991195.  The rsquared on the test data was -1.8520610214013103e+29.
# LOGIS: The rsquared on the training data was 0.9646497470281983.  The rsquared on the test data was -0.6903688041693936.

# %% [markdown]
# ### Evaluation
# From the training result, it seems that the linear regression model is performing quite bad. With logistic regression, the r2 score on training data is 0.965, which is quite good. However, the testing data shows the weakness of both the model. It means that the model overfitted on training data, and cannot be extended on new data.
